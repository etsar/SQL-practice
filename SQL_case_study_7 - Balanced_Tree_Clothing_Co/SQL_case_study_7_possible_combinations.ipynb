# %% [markdown]
# *Source of the case study:* https://8weeksqlchallenge.com/case-study-7/
#
# ---

# %% [markdown]
# ## Case Study #7 - Balanced Tree Clothing Co. - Possible combinations of any 3 products

# %% [markdown]
# You can find the entire output for all of 220 possible combinations below:

# %% [markdown]
# **Query #1**
#
#     SELECT s.prod_id, t1.prod_id, t2.prod_id, COUNT(*) AS combination_cnt
#     FROM balanced_tree.sales s
#     JOIN balanced_tree.sales t1 ON t1.txn_id = s.txn_id
#     AND s.prod_id < t1.prod_id
#     INNER JOIN balanced_tree.sales t2 ON t2.txn_id = s.txn_id
#     AND t1.prod_id < t2.prod_id
#     GROUP BY 1, 2, 3
#     ORDER BY 4 DESC;
#
# | prod_id | prod_id | prod_id | combination_cnt |
# | ------- | ------- | ------- | --------------- |
# | 5d267b  | 9ec847  | c8d436  | 352             |
# | 72f5d4  | e83aa3  | f084eb  | 349             |
# | 2a2353  | 9ec847  | c8d436  | 347             |
# | 2a2353  | 9ec847  | b9a74d  | 347             |
# | 5d267b  | c4a632  | c8d436  | 347             |
# | 2feb6b  | 9ec847  | e83aa3  | 347             |
# | 9ec847  | e83aa3  | f084eb  | 345             |
# | 5d267b  | 9ec847  | e83aa3  | 344             |
# | 2a2353  | 9ec847  | e83aa3  | 344             |
# | 72f5d4  | e31d39  | f084eb  | 342             |
# | 2a2353  | 72f5d4  | 9ec847  | 342             |
# | 2a2353  | 72f5d4  | c8d436  | 340             |
# | 2a2353  | 5d267b  | 9ec847  | 339             |
# | 2feb6b  | 9ec847  | f084eb  | 338             |
# | 9ec847  | b9a74d  | c4a632  | 338             |
# | 2a2353  | 5d267b  | c8d436  | 337             |
# | 5d267b  | c4a632  | e83aa3  | 336             |
# | 5d267b  | e83aa3  | f084eb  | 336             |
# | 5d267b  | c8d436  | f084eb  | 336             |
# | 9ec847  | b9a74d  | c8d436  | 336             |
# | 9ec847  | c4a632  | e83aa3  | 335             |
# | 2a2353  | 9ec847  | e31d39  | 335             |
# | 9ec847  | b9a74d  | f084eb  | 335             |
# | 2a2353  | c8d436  | e31d39  | 334             |
# | 2a2353  | b9a74d  | c8d436  | 334             |
# | 2feb6b  | 9ec847  | c4a632  | 334             |
# | 2a2353  | 5d267b  | e31d39  | 333             |
# | 5d267b  | c8d436  | d5e9a6  | 333             |
# | 2a2353  | 9ec847  | f084eb  | 333             |
# | 9ec847  | b9a74d  | e83aa3  | 333             |
# | 9ec847  | c4a632  | c8d436  | 333             |
# | 2feb6b  | 5d267b  | c4a632  | 332             |
# | 5d267b  | 9ec847  | f084eb  | 332             |
# | 72f5d4  | 9ec847  | f084eb  | 331             |
# | 9ec847  | c8d436  | d5e9a6  | 331             |
# | 2a2353  | e31d39  | f084eb  | 331             |
# | 72f5d4  | c8d436  | f084eb  | 331             |
# | 2feb6b  | e83aa3  | f084eb  | 331             |
# | 5d267b  | 72f5d4  | c4a632  | 331             |
# | 5d267b  | 72f5d4  | e83aa3  | 331             |
# | 2feb6b  | 9ec847  | b9a74d  | 330             |
# | 72f5d4  | 9ec847  | c8d436  | 330             |
# | 2a2353  | 72f5d4  | e31d39  | 330             |
# | 2feb6b  | c4a632  | c8d436  | 330             |
# | 5d267b  | 9ec847  | b9a74d  | 330             |
# | 9ec847  | c4a632  | f084eb  | 329             |
# | 5d267b  | 72f5d4  | c8d436  | 329             |
# | 2feb6b  | c4a632  | f084eb  | 329             |
# | 2a2353  | 9ec847  | c4a632  | 328             |
# | 2a2353  | 72f5d4  | f084eb  | 328             |
# | 2a2353  | 9ec847  | d5e9a6  | 328             |
# | 9ec847  | c8d436  | e83aa3  | 328             |
# | 5d267b  | 9ec847  | c4a632  | 328             |
# | 2a2353  | 5d267b  | 72f5d4  | 328             |
# | e31d39  | e83aa3  | f084eb  | 327             |
# | 2a2353  | b9a74d  | e31d39  | 327             |
# | 2a2353  | 2feb6b  | e31d39  | 327             |
# | 72f5d4  | b9a74d  | f084eb  | 326             |
# | 9ec847  | d5e9a6  | e83aa3  | 326             |
# | 5d267b  | 72f5d4  | 9ec847  | 326             |
# | 9ec847  | c4a632  | d5e9a6  | 326             |
# | 2a2353  | 5d267b  | e83aa3  | 326             |
# | 2feb6b  | 9ec847  | c8d436  | 326             |
# | 2a2353  | 2feb6b  | 9ec847  | 325             |
# | 2a2353  | c8d436  | d5e9a6  | 325             |
# | d5e9a6  | e31d39  | f084eb  | 325             |
# | 2feb6b  | 5d267b  | c8d436  | 324             |
# | c4a632  | e83aa3  | f084eb  | 324             |
# | 2feb6b  | 5d267b  | e83aa3  | 324             |
# | 5d267b  | c4a632  | f084eb  | 323             |
# | 2feb6b  | 9ec847  | d5e9a6  | 323             |
# | 2a2353  | c8d436  | f084eb  | 322             |
# | 5d267b  | 72f5d4  | f084eb  | 322             |
# | 72f5d4  | 9ec847  | e83aa3  | 322             |
# | 2feb6b  | c8d436  | f084eb  | 322             |
# | 9ec847  | d5e9a6  | f084eb  | 322             |
# | 2a2353  | c4a632  | c8d436  | 321             |
# | c4a632  | c8d436  | f084eb  | 321             |
# | 2a2353  | d5e9a6  | e31d39  | 321             |
# | 9ec847  | c8d436  | f084eb  | 320             |
# | 2feb6b  | 72f5d4  | f084eb  | 320             |
# | 72f5d4  | 9ec847  | b9a74d  | 320             |
# | 5d267b  | e31d39  | f084eb  | 320             |
# | 2feb6b  | c4a632  | e83aa3  | 320             |
# | 9ec847  | b9a74d  | e31d39  | 319             |
# | 2a2353  | 72f5d4  | e83aa3  | 319             |
# | 5d267b  | 9ec847  | d5e9a6  | 319             |
# | 2feb6b  | e31d39  | f084eb  | 319             |
# | 2a2353  | 72f5d4  | b9a74d  | 319             |
# | 2a2353  | 5d267b  | c4a632  | 319             |
# | 72f5d4  | b9a74d  | c8d436  | 318             |
# | 2a2353  | 5d267b  | d5e9a6  | 318             |
# | 2a2353  | 5d267b  | f084eb  | 318             |
# | b9a74d  | c8d436  | d5e9a6  | 318             |
# | c8d436  | e31d39  | f084eb  | 318             |
# | b9a74d  | c8d436  | e31d39  | 318             |
# | 72f5d4  | c8d436  | e31d39  | 318             |
# | 5d267b  | 72f5d4  | e31d39  | 317             |
# | 5d267b  | c4a632  | d5e9a6  | 317             |
# | 9ec847  | e31d39  | e83aa3  | 317             |
# | b9a74d  | c4a632  | c8d436  | 317             |
# | 9ec847  | e31d39  | f084eb  | 317             |
# | 5d267b  | b9a74d  | c8d436  | 316             |
# | 2feb6b  | 72f5d4  | c8d436  | 316             |
# | 72f5d4  | c4a632  | e83aa3  | 316             |
# | c8d436  | e83aa3  | f084eb  | 316             |
# | c4a632  | e31d39  | f084eb  | 316             |
# | 72f5d4  | 9ec847  | c4a632  | 315             |
# | 2feb6b  | 5d267b  | 9ec847  | 315             |
# | 2feb6b  | 72f5d4  | 9ec847  | 315             |
# | 2feb6b  | b9a74d  | c4a632  | 315             |
# | 72f5d4  | b9a74d  | e31d39  | 315             |
# | 72f5d4  | e31d39  | e83aa3  | 315             |
# | 9ec847  | c8d436  | e31d39  | 315             |
# | b9a74d  | e31d39  | f084eb  | 315             |
# | 2a2353  | c4a632  | e31d39  | 314             |
# | 5d267b  | b9a74d  | c4a632  | 314             |
# | b9a74d  | c4a632  | d5e9a6  | 314             |
# | 9ec847  | b9a74d  | d5e9a6  | 314             |
# | 2a2353  | 2feb6b  | c8d436  | 313             |
# | 72f5d4  | c4a632  | c8d436  | 313             |
# | 2feb6b  | c8d436  | d5e9a6  | 313             |
# | 5d267b  | c8d436  | e83aa3  | 313             |
# | 2feb6b  | 5d267b  | f084eb  | 313             |
# | 72f5d4  | c8d436  | e83aa3  | 313             |
# | 2feb6b  | 72f5d4  | e83aa3  | 313             |
# | c4a632  | c8d436  | e83aa3  | 312             |
# | 72f5d4  | c4a632  | f084eb  | 312             |
# | 5d267b  | d5e9a6  | f084eb  | 311             |
# | 72f5d4  | c8d436  | d5e9a6  | 311             |
# | d5e9a6  | e83aa3  | f084eb  | 311             |
# | b9a74d  | c8d436  | f084eb  | 311             |
# | 2feb6b  | b9a74d  | c8d436  | 310             |
# | 2feb6b  | c8d436  | e83aa3  | 310             |
# | 9ec847  | c4a632  | e31d39  | 310             |
# | 2feb6b  | 5d267b  | d5e9a6  | 310             |
# | 2feb6b  | b9a74d  | e31d39  | 310             |
# | b9a74d  | c4a632  | f084eb  | 310             |
# | 2a2353  | c8d436  | e83aa3  | 309             |
# | 9ec847  | d5e9a6  | e31d39  | 309             |
# | c8d436  | d5e9a6  | e31d39  | 309             |
# | c8d436  | d5e9a6  | f084eb  | 309             |
# | 2a2353  | d5e9a6  | f084eb  | 309             |
# | c4a632  | c8d436  | d5e9a6  | 308             |
# | 5d267b  | 9ec847  | e31d39  | 308             |
# | 2a2353  | b9a74d  | c4a632  | 308             |
# | 2a2353  | e31d39  | e83aa3  | 307             |
# | 72f5d4  | b9a74d  | e83aa3  | 307             |
# | 5d267b  | e31d39  | e83aa3  | 307             |
# | 5d267b  | d5e9a6  | e31d39  | 307             |
# | 2a2353  | 2feb6b  | f084eb  | 307             |
# | 2a2353  | 2feb6b  | b9a74d  | 307             |
# | 2feb6b  | b9a74d  | f084eb  | 307             |
# | 2a2353  | 2feb6b  | c4a632  | 307             |
# | 2a2353  | 2feb6b  | 5d267b  | 306             |
# | 5d267b  | b9a74d  | e83aa3  | 306             |
# | 72f5d4  | 9ec847  | d5e9a6  | 306             |
# | 2feb6b  | d5e9a6  | f084eb  | 306             |
# | c4a632  | d5e9a6  | f084eb  | 305             |
# | 2feb6b  | c8d436  | e31d39  | 305             |
# | 5d267b  | d5e9a6  | e83aa3  | 305             |
# | 2feb6b  | c4a632  | d5e9a6  | 305             |
# | 2a2353  | b9a74d  | f084eb  | 305             |
# | b9a74d  | d5e9a6  | f084eb  | 305             |
# | 2a2353  | 2feb6b  | 72f5d4  | 305             |
# | 2feb6b  | e31d39  | e83aa3  | 304             |
# | 2feb6b  | d5e9a6  | e31d39  | 304             |
# | c8d436  | e31d39  | e83aa3  | 304             |
# | 2feb6b  | c4a632  | e31d39  | 304             |
# | 2a2353  | 5d267b  | b9a74d  | 304             |
# | b9a74d  | e31d39  | e83aa3  | 304             |
# | 2feb6b  | 72f5d4  | b9a74d  | 303             |
# | 2feb6b  | 72f5d4  | e31d39  | 303             |
# | 5d267b  | b9a74d  | f084eb  | 302             |
# | 2feb6b  | 72f5d4  | c4a632  | 302             |
# | c4a632  | c8d436  | e31d39  | 302             |
# | 5d267b  | c8d436  | e31d39  | 302             |
# | 2a2353  | 72f5d4  | d5e9a6  | 301             |
# | 2a2353  | c4a632  | d5e9a6  | 301             |
# | 2feb6b  | 9ec847  | e31d39  | 301             |
# | c8d436  | d5e9a6  | e83aa3  | 301             |
# | 2feb6b  | d5e9a6  | e83aa3  | 300             |
# | 5d267b  | b9a74d  | d5e9a6  | 300             |
# | 5d267b  | 72f5d4  | d5e9a6  | 300             |
# | 5d267b  | 72f5d4  | b9a74d  | 300             |
# | b9a74d  | c4a632  | e83aa3  | 300             |
# | 72f5d4  | d5e9a6  | f084eb  | 299             |
# | 2feb6b  | b9a74d  | d5e9a6  | 299             |
# | 2a2353  | 72f5d4  | c4a632  | 299             |
# | 72f5d4  | 9ec847  | e31d39  | 299             |
# | 2feb6b  | 5d267b  | b9a74d  | 299             |
# | 2a2353  | b9a74d  | e83aa3  | 298             |
# | 2a2353  | e83aa3  | f084eb  | 298             |
# | 72f5d4  | b9a74d  | c4a632  | 298             |
# | 2a2353  | b9a74d  | d5e9a6  | 298             |
# | 72f5d4  | d5e9a6  | e31d39  | 297             |
# | b9a74d  | d5e9a6  | e31d39  | 297             |
# | 72f5d4  | d5e9a6  | e83aa3  | 297             |
# | 72f5d4  | c4a632  | e31d39  | 296             |
# | b9a74d  | e83aa3  | f084eb  | 296             |
# | 72f5d4  | b9a74d  | d5e9a6  | 296             |
# | b9a74d  | c8d436  | e83aa3  | 296             |
# | c4a632  | d5e9a6  | e83aa3  | 296             |
# | 2feb6b  | b9a74d  | e83aa3  | 295             |
# | 2a2353  | d5e9a6  | e83aa3  | 295             |
# | c4a632  | e31d39  | e83aa3  | 294             |
# | 2a2353  | c4a632  | f084eb  | 294             |
# | 5d267b  | c4a632  | e31d39  | 294             |
# | b9a74d  | c4a632  | e31d39  | 293             |
# | 2a2353  | 2feb6b  | e83aa3  | 293             |
# | c4a632  | d5e9a6  | e31d39  | 293             |
# | 2feb6b  | 5d267b  | 72f5d4  | 293             |
# | 2a2353  | c4a632  | e83aa3  | 292             |
# | 2a2353  | 2feb6b  | d5e9a6  | 292             |
# | b9a74d  | d5e9a6  | e83aa3  | 291             |
# | 2feb6b  | 5d267b  | e31d39  | 290             |
# | 2feb6b  | 72f5d4  | d5e9a6  | 289             |
# | 5d267b  | b9a74d  | e31d39  | 288             |
# | 72f5d4  | c4a632  | d5e9a6  | 287             |
# | d5e9a6  | e31d39  | e83aa3  | 283             |
#
# ---
